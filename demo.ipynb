# %%
# Код для импорта модулей и данных из корня репозитория (нужен для работы из других папок)

import sys

core_path = '../..'
sys.path.insert(0, core_path)

# %%
# Генерация параметров для конфигурации ConfigurationEEE

import json
from contact_center_simulator.configurations import ConfigurationEEE

params = ConfigurationEEE().gen_params(
    agents_range=(3, 3),
    services_range=(1, 1),
    services_intensities_range=(50, 100),
    services_churn_range=(100, 200),
    max_s_per_a_number=3,
    agents_handling_time_mean_range=(20, 100)
)

params_file_name = "EEE_3a_1s.json"

with open(f'./params/{params_file_name}', 'w', encoding='ascii') as f_obj:
    json.dump(params, f_obj, indent=4)

# %%
# Генерация параметров для конфигурации ConfigurationEEL

import json
from contact_center_simulator.configurations import ConfigurationEEL

params = ConfigurationEEL().gen_params(
    agents_range=(10, 10),
    services_range=(6, 6),
    services_intensities_range=(50, 100),
    services_churn_range=(100, 200),
    max_s_per_a_number=3,
    agents_handling_time_mean_range=(20, 100),
    agents_handling_time_std_range=(0, 0)
)

params_file_name = "EEL_10a_6s.json"

with open(f'./params/{params_file_name}', 'w', encoding='ascii') as f_obj:
    json.dump(params, f_obj, indent=4)

# %%
import json
from contact_center_simulator.configurations import ConfigurationEEL
from contact_center_simulator.generator import Generator


# ПАРАМЕТРЫ КОНФИГУРАЦИИ

params_file_name = 'EEL_10a_6s.json'

with open(f'./params/{params_file_name}', 'r', encoding='ascii') as f_obj:

    params = json.load(f_obj)

# ЗАПУСК

g = Generator(
    methods=ConfigurationEEL(),
    general_timer=10,
    services_statuses_recount_timer=5)

x = g.events_iterator(
    shared_params=params,
    time_scale = 0.0,
    number_of_calls=30)

for e in range(1000):
    print(next(x))
# Out:
# CallEvent(time_handle=5.94829968713204, interaction_id='01f45478-0f31-44c0-8cee-5d2309f5a95e', service_id='S_3', weight=1.0)
# ToAgentEvent(time_handle=5.94829968713204, interaction_id='01f45478-0f31-44c0-8cee-5d2309f5a95e', service_id='S_3', weight=1.0, agent_id='A_04', generated_handling_time=76.0)
# TimerEvent(time_handle=10, real_time=1771707630.548481, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=20, real_time=1771707630.548688, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=30, real_time=1771707630.548874, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=38.02944993389158, interaction_id='c71e9f10-ac29-44b0-84c4-c6f5fa5cfab4', service_id='S_4', weight=1.0)
# ToAgentEvent(time_handle=38.02944993389158, interaction_id='c71e9f10-ac29-44b0-84c4-c6f5fa5cfab4', service_id='S_4', weight=1.0, agent_id='A_01', generated_handling_time=21.0)
# TimerEvent(time_handle=40, real_time=1771707630.549336, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=50, real_time=1771707630.549505, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=58.34126295750331, interaction_id='c6e83325-763e-44b6-90a7-c7b6efa9dac4', service_id='S_6', weight=1.0)
# ToAgentEvent(time_handle=58.34126295750331, interaction_id='c6e83325-763e-44b6-90a7-c7b6efa9dac4', service_id='S_6', weight=1.0, agent_id='A_02', generated_handling_time=95.0)
# FinishEvent(time_handle=59.02944993389158, interaction_id='c71e9f10-ac29-44b0-84c4-c6f5fa5cfab4', service_id='S_4', agent_id='A_01', handling_time=21.0)
# TimerEvent(time_handle=60, real_time=1771707630.550203, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=62.63388301817159, interaction_id='529d0ccc-af92-43fe-b7a0-be8f8e0df542', service_id='S_3', weight=1.0)
# ToAgentEvent(time_handle=62.63388301817159, interaction_id='529d0ccc-af92-43fe-b7a0-be8f8e0df542', service_id='S_3', weight=1.0, agent_id='A_05', generated_handling_time=83.99999999999999)
# CallEvent(time_handle=68.33678456954316, interaction_id='85b63080-23e1-4683-81c8-8392f3d3110a', service_id='S_1', weight=1.0)
# ToAgentEvent(time_handle=68.33678456954316, interaction_id='85b63080-23e1-4683-81c8-8392f3d3110a', service_id='S_1', weight=1.0, agent_id='A_06', generated_handling_time=70.00000000000003)
# TimerEvent(time_handle=70, real_time=1771707630.550992, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=80, real_time=1771707630.551153, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=81.94829968713204, interaction_id='01f45478-0f31-44c0-8cee-5d2309f5a95e', service_id='S_3', agent_id='A_04', handling_time=76.0)
# TimerEvent(time_handle=90, real_time=1771707630.551459, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=94.90092299250918, interaction_id='27f5bbc4-f0ff-43c7-b4b0-b0577e6d7bb4', service_id='S_3', weight=1.0)
# ToAgentEvent(time_handle=94.90092299250918, interaction_id='27f5bbc4-f0ff-43c7-b4b0-b0577e6d7bb4', service_id='S_3', weight=1.0, agent_id='A_07', generated_handling_time=56.00000000000002)
# TimerEvent(time_handle=100, real_time=1771707630.551823, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=110, real_time=1771707630.551969, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=120, real_time=1771707630.552113, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=130, real_time=1771707630.55226, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=136.31495302438987, interaction_id='50afb03c-5595-4698-b694-f7b2bf6fd2bd', service_id='S_1', weight=1.0)
# ToAgentEvent(time_handle=136.31495302438987, interaction_id='50afb03c-5595-4698-b694-f7b2bf6fd2bd', service_id='S_1', weight=1.0, agent_id='A_09', generated_handling_time=34.00000000000001)
# FinishEvent(time_handle=138.33678456954317, interaction_id='85b63080-23e1-4683-81c8-8392f3d3110a', service_id='S_1', agent_id='A_06', handling_time=70.00000000000003)
# TimerEvent(time_handle=140, real_time=1771707630.552751, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=141.42112963514617, interaction_id='854e9d42-55df-4752-a0e9-e0cb7d2be180', service_id='S_1', weight=1.0)
# ToAgentEvent(time_handle=141.42112963514617, interaction_id='854e9d42-55df-4752-a0e9-e0cb7d2be180', service_id='S_1', weight=1.0, agent_id='A_06', generated_handling_time=70.00000000000003)
# FinishEvent(time_handle=146.63388301817156, interaction_id='529d0ccc-af92-43fe-b7a0-be8f8e0df542', service_id='S_3', agent_id='A_05', handling_time=83.99999999999999)
# TimerEvent(time_handle=150, real_time=1771707630.55322, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=150.9009229925092, interaction_id='27f5bbc4-f0ff-43c7-b4b0-b0577e6d7bb4', service_id='S_3', agent_id='A_07', handling_time=56.00000000000002)
# FinishEvent(time_handle=153.34126295750332, interaction_id='c6e83325-763e-44b6-90a7-c7b6efa9dac4', service_id='S_6', agent_id='A_02', handling_time=95.0)
# TimerEvent(time_handle=160, real_time=1771707630.553841, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=165.8902552818845, interaction_id='454670e4-b0d6-416c-823d-6d238821ff48', service_id='S_2', weight=1.0)
# ToAgentEvent(time_handle=165.8902552818845, interaction_id='454670e4-b0d6-416c-823d-6d238821ff48', service_id='S_2', weight=1.0, agent_id='A_03', generated_handling_time=23.0)
# TimerEvent(time_handle=170, real_time=1771707630.554236, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=170.31495302438987, interaction_id='50afb03c-5595-4698-b694-f7b2bf6fd2bd', service_id='S_1', agent_id='A_09', handling_time=34.00000000000001)
# TimerEvent(time_handle=180, real_time=1771707630.554521, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=188.8902552818845, interaction_id='454670e4-b0d6-416c-823d-6d238821ff48', service_id='S_2', agent_id='A_03', handling_time=23.0)
# TimerEvent(time_handle=190, real_time=1771707630.554813, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=200, real_time=1771707630.554952, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=205.05660369788671, interaction_id='f71573c4-0577-43e5-817e-c1327ece2361', service_id='S_1', weight=1.0)
# ToAgentEvent(time_handle=205.05660369788671, interaction_id='f71573c4-0577-43e5-817e-c1327ece2361', service_id='S_1', weight=1.0, agent_id='A_02', generated_handling_time=49.99999999999999)
# TimerEvent(time_handle=210, real_time=1771707630.555286, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=211.4211296351462, interaction_id='854e9d42-55df-4752-a0e9-e0cb7d2be180', service_id='S_1', agent_id='A_06', handling_time=70.00000000000003)
# CallEvent(time_handle=219.5889170787188, interaction_id='e4ef1077-c874-46c0-be80-7601b810e0a8', service_id='S_2', weight=1.0)
# ToAgentEvent(time_handle=219.5889170787188, interaction_id='e4ef1077-c874-46c0-be80-7601b810e0a8', service_id='S_2', weight=1.0, agent_id='A_08', generated_handling_time=79.99999999999997)
# TimerEvent(time_handle=220, real_time=1771707630.555739, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=230, real_time=1771707630.555876, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=240, real_time=1771707630.556033, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=247.71115327858217, interaction_id='633b5780-6193-43a7-92f6-4f5cf01ef9f0', service_id='S_4', weight=1.0)
# ToAgentEvent(time_handle=247.71115327858217, interaction_id='633b5780-6193-43a7-92f6-4f5cf01ef9f0', service_id='S_4', weight=1.0, agent_id='A_01', generated_handling_time=21.0)
# CallEvent(time_handle=248.3114317676365, interaction_id='a0776f3e-d881-41ef-ba15-05d5807b1246', service_id='S_5', weight=1.0)
# ToAgentEvent(time_handle=248.3114317676365, interaction_id='a0776f3e-d881-41ef-ba15-05d5807b1246', service_id='S_5', weight=1.0, agent_id='A_04', generated_handling_time=56.00000000000002)
# TimerEvent(time_handle=250, real_time=1771707630.556515, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=255.05660369788671, interaction_id='f71573c4-0577-43e5-817e-c1327ece2361', service_id='S_1', agent_id='A_02', handling_time=49.99999999999999)
# CallEvent(time_handle=259.7331260652269, interaction_id='3594becf-0d6d-4d16-9162-cded77635325', service_id='S_6', weight=1.0)
# ToAgentEvent(time_handle=259.7331260652269, interaction_id='3594becf-0d6d-4d16-9162-cded77635325', service_id='S_6', weight=1.0, agent_id='A_07', generated_handling_time=62.00000000000001)
# TimerEvent(time_handle=260, real_time=1771707630.556959, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=264.92305284036786, interaction_id='97ff26e3-a6ef-4f58-a923-497e201caddc', service_id='S_6', weight=1.0)
# ToAgentEvent(time_handle=264.92305284036786, interaction_id='97ff26e3-a6ef-4f58-a923-497e201caddc', service_id='S_6', weight=1.0, agent_id='A_09', generated_handling_time=62.99999999999999)
# FinishEvent(time_handle=268.7111532785822, interaction_id='633b5780-6193-43a7-92f6-4f5cf01ef9f0', service_id='S_4', agent_id='A_01', handling_time=21.0)
# TimerEvent(time_handle=270, real_time=1771707630.55741, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=277.4727301534588, interaction_id='d63d2090-d9f3-426c-8579-7137f1e1a6ef', service_id='S_1', weight=1.0)
# ToAgentEvent(time_handle=277.4727301534588, interaction_id='d63d2090-d9f3-426c-8579-7137f1e1a6ef', service_id='S_1', weight=1.0, agent_id='A_06', generated_handling_time=70.00000000000003)
# TimerEvent(time_handle=280, real_time=1771707630.557708, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=290, real_time=1771707630.557831, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=299.58891707871874, interaction_id='e4ef1077-c874-46c0-be80-7601b810e0a8', service_id='S_2', agent_id='A_08', handling_time=79.99999999999997)
# TimerEvent(time_handle=300, real_time=1771707630.558076, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=303.08549872402097, interaction_id='ce9e9128-ab1f-46dc-bd09-0e1f90aa4477', service_id='S_5', weight=1.0)
# ToAgentEvent(time_handle=303.08549872402097, interaction_id='ce9e9128-ab1f-46dc-bd09-0e1f90aa4477', service_id='S_5', weight=1.0, agent_id='A_05', generated_handling_time=44.99999999999999)
# FinishEvent(time_handle=304.3114317676365, interaction_id='a0776f3e-d881-41ef-ba15-05d5807b1246', service_id='S_5', agent_id='A_04', handling_time=56.00000000000002)
# TimerEvent(time_handle=310, real_time=1771707630.558473, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=315.57759301633376, interaction_id='bf195396-8825-41db-91d2-786dd1820bdc', service_id='S_3', weight=1.0)
# ToAgentEvent(time_handle=315.57759301633376, interaction_id='bf195396-8825-41db-91d2-786dd1820bdc', service_id='S_3', weight=1.0, agent_id='A_10', generated_handling_time=100.00000000000004)
# TimerEvent(time_handle=320, real_time=1771707630.558746, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=321.7331260652269, interaction_id='3594becf-0d6d-4d16-9162-cded77635325', service_id='S_6', agent_id='A_07', handling_time=62.00000000000001)
# FinishEvent(time_handle=327.92305284036786, interaction_id='97ff26e3-a6ef-4f58-a923-497e201caddc', service_id='S_6', agent_id='A_09', handling_time=62.99999999999999)
# CallEvent(time_handle=329.6175333506327, interaction_id='4b563414-5631-4b36-932f-aef84919162b', service_id='S_6', weight=1.0)
# ToAgentEvent(time_handle=329.6175333506327, interaction_id='4b563414-5631-4b36-932f-aef84919162b', service_id='S_6', weight=1.0, agent_id='A_02', generated_handling_time=95.0)
# CallEvent(time_handle=329.8537580320462, interaction_id='0fc0cf26-0c7b-45a2-9353-8e05f7577012', service_id='S_4', weight=1.0)
# ToAgentEvent(time_handle=329.8537580320462, interaction_id='0fc0cf26-0c7b-45a2-9353-8e05f7577012', service_id='S_4', weight=1.0, agent_id='A_03', generated_handling_time=29.000000000000004)
# TimerEvent(time_handle=330, real_time=1771707630.559413, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=331.4232110442083, interaction_id='112ec0e1-42d7-4e8e-a17d-d5cf3ca20099', service_id='S_4', weight=1.0)
# ToAgentEvent(time_handle=331.4232110442083, interaction_id='112ec0e1-42d7-4e8e-a17d-d5cf3ca20099', service_id='S_4', weight=1.0, agent_id='A_01', generated_handling_time=21.0)
# TimerEvent(time_handle=340, real_time=1771707630.559686, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=347.4727301534589, interaction_id='d63d2090-d9f3-426c-8579-7137f1e1a6ef', service_id='S_1', agent_id='A_06', handling_time=70.00000000000003)
# FinishEvent(time_handle=348.08549872402097, interaction_id='ce9e9128-ab1f-46dc-bd09-0e1f90aa4477', service_id='S_5', agent_id='A_05', handling_time=44.99999999999999)
# TimerEvent(time_handle=350, real_time=1771707630.56006, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=352.4232110442083, interaction_id='112ec0e1-42d7-4e8e-a17d-d5cf3ca20099', service_id='S_4', agent_id='A_01', handling_time=21.0)
# CallEvent(time_handle=358.77775022612957, interaction_id='56f61a17-ed55-48fe-930f-eeb0693d008e', service_id='S_6', weight=1.0)
# ToAgentEvent(time_handle=358.77775022612957, interaction_id='56f61a17-ed55-48fe-930f-eeb0693d008e', service_id='S_6', weight=1.0, agent_id='A_07', generated_handling_time=62.00000000000001)
# FinishEvent(time_handle=358.8537580320462, interaction_id='0fc0cf26-0c7b-45a2-9353-8e05f7577012', service_id='S_4', agent_id='A_03', handling_time=29.000000000000004)
# TimerEvent(time_handle=360, real_time=1771707630.560669, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=370, real_time=1771707630.560828, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=380, real_time=1771707630.560958, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=390, real_time=1771707630.561088, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=400, real_time=1771707630.56122, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=410, real_time=1771707630.561348, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=415.5775930163338, interaction_id='bf195396-8825-41db-91d2-786dd1820bdc', service_id='S_3', agent_id='A_10', handling_time=100.00000000000004)
# TimerEvent(time_handle=420, real_time=1771707630.561613, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=420.77775022612957, interaction_id='56f61a17-ed55-48fe-930f-eeb0693d008e', service_id='S_6', agent_id='A_07', handling_time=62.00000000000001)
# FinishEvent(time_handle=424.6175333506327, interaction_id='4b563414-5631-4b36-932f-aef84919162b', service_id='S_6', agent_id='A_02', handling_time=95.0)
# TimerEvent(time_handle=430, real_time=1771707630.562009, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=430.27264367873056, interaction_id='113b0a65-d1ca-430a-9234-fae29c73e8bd', service_id='S_4', weight=1.0)
# ToAgentEvent(time_handle=430.27264367873056, interaction_id='113b0a65-d1ca-430a-9234-fae29c73e8bd', service_id='S_4', weight=1.0, agent_id='A_09', generated_handling_time=33.0)
# TimerEvent(time_handle=440, real_time=1771707630.562458, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=446.83618051375163, interaction_id='c654a06f-527a-4b57-81ed-ef0c3599a5f0', service_id='S_5', weight=1.0)
# ToAgentEvent(time_handle=446.83618051375163, interaction_id='c654a06f-527a-4b57-81ed-ef0c3599a5f0', service_id='S_5', weight=1.0, agent_id='A_04', generated_handling_time=56.00000000000002)
# TimerEvent(time_handle=450, real_time=1771707630.5628, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=460, real_time=1771707630.56293, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=463.27264367873056, interaction_id='113b0a65-d1ca-430a-9234-fae29c73e8bd', service_id='S_4', agent_id='A_09', handling_time=33.0)
# TimerEvent(time_handle=470, real_time=1771707630.563184, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=480, real_time=1771707630.563308, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=481.12542375404644, interaction_id='16c756e9-92cd-4162-b383-8d79aafc0162', service_id='S_3', weight=1.0)
# ToAgentEvent(time_handle=481.12542375404644, interaction_id='16c756e9-92cd-4162-b383-8d79aafc0162', service_id='S_3', weight=1.0, agent_id='A_08', generated_handling_time=63.99999999999998)
# CallEvent(time_handle=483.81292365511416, interaction_id='17ab7a6d-75ba-4858-b3c6-f2479fa4c6ff', service_id='S_4', weight=1.0)
# ToAgentEvent(time_handle=483.81292365511416, interaction_id='17ab7a6d-75ba-4858-b3c6-f2479fa4c6ff', service_id='S_4', weight=1.0, agent_id='A_01', generated_handling_time=21.0)
# TimerEvent(time_handle=490, real_time=1771707630.563711, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=500, real_time=1771707630.563826, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=502.83618051375163, interaction_id='c654a06f-527a-4b57-81ed-ef0c3599a5f0', service_id='S_5', agent_id='A_04', handling_time=56.00000000000002)
# FinishEvent(time_handle=504.81292365511416, interaction_id='17ab7a6d-75ba-4858-b3c6-f2479fa4c6ff', service_id='S_4', agent_id='A_01', handling_time=21.0)
# TimerEvent(time_handle=510, real_time=1771707630.564161, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=520, real_time=1771707630.564273, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=523.0653391176372, interaction_id='a4a1a6a8-74cd-4cf3-bfcf-e5e9265a65ce', service_id='S_1', weight=1.0)
# ToAgentEvent(time_handle=523.0653391176372, interaction_id='a4a1a6a8-74cd-4cf3-bfcf-e5e9265a65ce', service_id='S_1', weight=1.0, agent_id='A_06', generated_handling_time=70.00000000000003)
# CallEvent(time_handle=527.4457840558505, interaction_id='54225540-4b56-4030-a510-aa01e63bbe47', service_id='S_2', weight=1.0)
# ToAgentEvent(time_handle=527.4457840558505, interaction_id='54225540-4b56-4030-a510-aa01e63bbe47', service_id='S_2', weight=1.0, agent_id='A_03', generated_handling_time=23.0)
# TimerEvent(time_handle=530, real_time=1771707630.564654, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=540, real_time=1771707630.564766, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=545.1254237540464, interaction_id='16c756e9-92cd-4162-b383-8d79aafc0162', service_id='S_3', agent_id='A_08', handling_time=63.99999999999998)
# TimerEvent(time_handle=550, real_time=1771707630.564989, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=550.4457840558505, interaction_id='54225540-4b56-4030-a510-aa01e63bbe47', service_id='S_2', agent_id='A_03', handling_time=23.0)
# TimerEvent(time_handle=560, real_time=1771707630.565209, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=570, real_time=1771707630.565319, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=580, real_time=1771707630.565429, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=590, real_time=1771707630.565538, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=593.0653391176372, interaction_id='a4a1a6a8-74cd-4cf3-bfcf-e5e9265a65ce', service_id='S_1', agent_id='A_06', handling_time=70.00000000000003)
# CallEvent(time_handle=596.2555346052467, interaction_id='52dd536b-fcc6-4fc7-ab18-f61a10639e33', service_id='S_6', weight=1.0)
# ToAgentEvent(time_handle=596.2555346052467, interaction_id='52dd536b-fcc6-4fc7-ab18-f61a10639e33', service_id='S_6', weight=1.0, agent_id='A_07', generated_handling_time=62.00000000000001)
# TimerEvent(time_handle=600, real_time=1771707630.566368, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=610, real_time=1771707630.566924, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=620, real_time=1771707630.567178, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=630, real_time=1771707630.56731, start_time=1771707630.546842, timer_period=10)
# CallEvent(time_handle=635.0268939795366, interaction_id='1ab56ad0-9752-43ab-aee2-787f26009f43', service_id='S_5', weight=1.0)
# ToAgentEvent(time_handle=635.0268939795366, interaction_id='1ab56ad0-9752-43ab-aee2-787f26009f43', service_id='S_5', weight=1.0, agent_id='A_05', generated_handling_time=44.99999999999999)
# TimerEvent(time_handle=640, real_time=1771707630.567739, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=650, real_time=1771707630.56788, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=658.2555346052467, interaction_id='52dd536b-fcc6-4fc7-ab18-f61a10639e33', service_id='S_6', agent_id='A_07', handling_time=62.00000000000001)
# TimerEvent(time_handle=660, real_time=1771707630.568126, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=670, real_time=1771707630.568248, start_time=1771707630.546842, timer_period=10)
# TimerEvent(time_handle=680, real_time=1771707630.568481, start_time=1771707630.546842, timer_period=10)
# FinishEvent(time_handle=680.0268939795366, interaction_id='1ab56ad0-9752-43ab-aee2-787f26009f43', service_id='S_5', agent_id='A_05', handling_time=44.99999999999999)
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[6], line 27
#      21 x = g.events_iterator(
#      22     shared_params=params,
#      23     time_scale = 0.0,
#      24     number_of_calls=30)
#      26 for e in range(1000):
# ---> 27     print(next(x))
#
# StopIteration:

# %%
import sys
import json
from loguru import logger
from contact_center_simulator.configurations import ConfigurationEEL
from contact_center_simulator.runner import Runner
from contact_center_simulator.estimators import (
    EWT0,
    LES
)

# ПАРАМЕТРЫ КОНФИГУРАЦИИ

config_file_name = 'EEL_10a_6s.json'

with open(f'./params/{config_file_name}', 'r', encoding='ascii') as f_obj:
    params = json.load(f_obj)

# СПОСОБЫ ИЗМЕРЕНИЯ EWT

estimators = [
    EWT0(service_ids=params['service_ids']),
    LES()
]

# КОНФИГУРАЦИЯ ЛОГОВ

logger.remove()
custom_format = (
    "<green>{time:YYYY-MM-DD HH:mm:ss.SSS}</green>\t"
    "<level>{level: <4}</level>\t"
    "<cyan>{name}</cyan>:<cyan>{function}</cyan>:<cyan>{line}</cyan>\t"
    "<level>{message}</level>"
)

# Логи в файл

logger.add('data.csv', level='INFO', format=custom_format)

# Логи в консоль

logger.add(sys.stderr, level='INFO', format=custom_format)
# logger.add(sys.stderr, level='DEBUG', format=custom_format)
# logger.add(sys.stderr, level='TRACE', format=custom_format)

# ЗАПУСК

runner = Runner(
    methods=ConfigurationEEL(),
    general_timer=1,
    services_statuses_recount_timer=5,
    ewt_estimators=estimators,
    logger=logger
)

runner.run(
    shared_params=params,
    time_scale=0.01667,
    number_of_calls=10)
# Out:
# 2026-02-22 00:01:54.659	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "CallEvent", "time_handle": 17.01848963451785, "interaction_id": "fcf3d1ea-0a6d-41d9-a2e9-b96524d927c5", "service_id": "S_1", "weight": 1.0}
# 2026-02-22 00:01:54.660	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "ToAgentEvent", "time_handle": 17.01848963451785, "interaction_id": "fcf3d1ea-0a6d-41d9-a2e9-b96524d927c5", "service_id": "S_1", "weight": 1.0, "agent_id": "A_02", "generated_handling_time": 49.99999999999999}
# 2026-02-22 00:01:55.269	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "CallEvent", "time_handle": 45.86419658271443, "interaction_id": "1e2fc633-8739-4c48-ab90-68672512d847", "service_id": "S_1", "weight": 1.0}
# 2026-02-22 00:01:55.270	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "ToAgentEvent", "time_handle": 45.86419658271443, "interaction_id": "1e2fc633-8739-4c48-ab90-68672512d847", "service_id": "S_1", "weight": 1.0, "agent_id": "A_06", "generated_handling_time": 70.00000000000003}
# 2026-02-22 00:01:55.728	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "FinishEvent", "time_handle": 67.01848963451783, "interaction_id": "fcf3d1ea-0a6d-41d9-a2e9-b96524d927c5", "service_id": "S_1", "agent_id": "A_02", "handling_time": 49.99999999999999}
# 2026-02-22 00:01:55.944	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "CallEvent", "time_handle": 76.80183068719639, "interaction_id": "72dc8d89-4694-4e5a-9918-6497db47a258", "service_id": "S_2", "weight": 1.0}
# 2026-02-22 00:01:55.944	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "ToAgentEvent", "time_handle": 76.80183068719639, "interaction_id": "72dc8d89-4694-4e5a-9918-6497db47a258", "service_id": "S_2", "weight": 1.0, "agent_id": "A_03", "generated_handling_time": 23.0}
# 2026-02-22 00:01:56.069	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "CallEvent", "time_handle": 82.14638454092551, "interaction_id": "d2986ca0-ee41-442c-bd99-91d1570c3066", "service_id": "S_4", "weight": 1.0}
# 2026-02-22 00:01:56.069	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "ToAgentEvent", "time_handle": 82.14638454092551, "interaction_id": "d2986ca0-ee41-442c-bd99-91d1570c3066", "service_id": "S_4", "weight": 1.0, "agent_id": "A_01", "generated_handling_time": 21.0}
# 2026-02-22 00:01:56.219	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "CallEvent", "time_handle": 88.79898236660031, "interaction_id": "7e4721f6-16f7-4dc7-84ed-26e57faefaba", "service_id": "S_4", "weight": 1.0}
# 2026-02-22 00:01:56.220	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "ToAgentEvent", "time_handle": 88.79898236660031, "interaction_id": "7e4721f6-16f7-4dc7-84ed-26e57faefaba", "service_id": "S_4", "weight": 1.0, "agent_id": "A_09", "generated_handling_time": 33.0}
# 2026-02-22 00:01:56.465	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "FinishEvent", "time_handle": 99.80183068719639, "interaction_id": "72dc8d89-4694-4e5a-9918-6497db47a258", "service_id": "S_2", "agent_id": "A_03", "handling_time": 23.0}
# 2026-02-22 00:01:56.547	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "FinishEvent", "time_handle": 103.14638454092551, "interaction_id": "d2986ca0-ee41-442c-bd99-91d1570c3066", "service_id": "S_4", "agent_id": "A_01", "handling_time": 21.0}
# 2026-02-22 00:01:56.603	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "CallEvent", "time_handle": 105.28491464129934, "interaction_id": "a94ac4bb-849b-46be-8928-f566b9412d28", "service_id": "S_6", "weight": 1.0}
# 2026-02-22 00:01:56.603	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "ToAgentEvent", "time_handle": 105.28491464129934, "interaction_id": "a94ac4bb-849b-46be-8928-f566b9412d28", "service_id": "S_6", "weight": 1.0, "agent_id": "A_07", "generated_handling_time": 62.00000000000001}
# 2026-02-22 00:01:56.836	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "FinishEvent", "time_handle": 115.86419658271446, "interaction_id": "1e2fc633-8739-4c48-ab90-68672512d847", "service_id": "S_1", "agent_id": "A_06", "handling_time": 70.00000000000003}
# 2026-02-22 00:01:56.976	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "FinishEvent", "time_handle": 121.79898236660031, "interaction_id": "7e4721f6-16f7-4dc7-84ed-26e57faefaba", "service_id": "S_4", "agent_id": "A_09", "handling_time": 33.0}
# 2026-02-22 00:01:57.407	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "CallEvent", "time_handle": 142.13578673451346, "interaction_id": "b96432bc-a278-468a-a5d8-62ee608e4252", "service_id": "S_1", "weight": 1.0}
# 2026-02-22 00:01:57.408	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "ToAgentEvent", "time_handle": 142.13578673451346, "interaction_id": "b96432bc-a278-468a-a5d8-62ee608e4252", "service_id": "S_1", "weight": 1.0, "agent_id": "A_02", "generated_handling_time": 49.99999999999999}
# 2026-02-22 00:01:57.422	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "CallEvent", "time_handle": 142.3255277497111, "interaction_id": "d912e520-e297-46f7-b4bb-5b780d49c7f3", "service_id": "S_3", "weight": 1.0}
# 2026-02-22 00:01:57.422	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "ToAgentEvent", "time_handle": 142.3255277497111, "interaction_id": "d912e520-e297-46f7-b4bb-5b780d49c7f3", "service_id": "S_3", "weight": 1.0, "agent_id": "A_04", "generated_handling_time": 76.0}
# 2026-02-22 00:01:57.935	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "FinishEvent", "time_handle": 167.28491464129934, "interaction_id": "a94ac4bb-849b-46be-8928-f566b9412d28", "service_id": "S_6", "agent_id": "A_07", "handling_time": 62.00000000000001}
# 2026-02-22 00:01:58.094	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "CallEvent", "time_handle": 174.91392714907306, "interaction_id": "5e285ad6-97fa-44d1-a984-debafe457bf8", "service_id": "S_2", "weight": 1.0}
# 2026-02-22 00:01:58.095	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "ToAgentEvent", "time_handle": 174.91392714907306, "interaction_id": "5e285ad6-97fa-44d1-a984-debafe457bf8", "service_id": "S_2", "weight": 1.0, "agent_id": "A_08", "generated_handling_time": 79.99999999999997}
# 2026-02-22 00:01:58.472	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "FinishEvent", "time_handle": 192.13578673451346, "interaction_id": "b96432bc-a278-468a-a5d8-62ee608e4252", "service_id": "S_1", "agent_id": "A_02", "handling_time": 49.99999999999999}
# 2026-02-22 00:01:59.028	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "FinishEvent", "time_handle": 218.3255277497111, "interaction_id": "d912e520-e297-46f7-b4bb-5b780d49c7f3", "service_id": "S_3", "agent_id": "A_04", "handling_time": 76.0}
# 2026-02-22 00:01:59.787	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "FinishEvent", "time_handle": 254.91392714907303, "interaction_id": "5e285ad6-97fa-44d1-a984-debafe457bf8", "service_id": "S_2", "agent_id": "A_08", "handling_time": 79.99999999999997}
# 2026-02-22 00:02:00.806	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "CallEvent", "time_handle": 304.6738052714314, "interaction_id": "36d550d5-9a9d-471a-bab1-3abffa7bdb80", "service_id": "S_5", "weight": 1.0}
# 2026-02-22 00:02:00.810	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "ToAgentEvent", "time_handle": 304.6738052714314, "interaction_id": "36d550d5-9a9d-471a-bab1-3abffa7bdb80", "service_id": "S_5", "weight": 1.0, "agent_id": "A_05", "generated_handling_time": 44.99999999999999}
# 2026-02-22 00:02:01.737	INFO	contact_center_simulator.runner:event_logger:82	FUNC_FINISH	{"event_type": "FinishEvent", "time_handle": 349.6738052714314, "interaction_id": "36d550d5-9a9d-471a-bab1-3abffa7bdb80", "service_id": "S_5", "agent_id": "A_05", "handling_time": 44.99999999999999}

# %%
# Запуск в режиме демо с API и EWT

import sys
import json
import psutil
# import time
# from copy import deepcopy
from multiprocessing import Process, Manager
from fastapi import FastAPI
from fastapi.responses import PlainTextResponse
import uvicorn
from loguru import logger

from contact_center_simulator.configurations import ConfigurationEEL, ParamsEEL as CurrentParams
from contact_center_simulator.runner import Runner
from contact_center_simulator.estimators import (
    EWT0
)

# ПАРАМЕТРЫ КОНФИГУРАЦИИ

config_file_name = 'EEL_10a_6s.json'

with open(f'./params/{config_file_name}', 'r', encoding='ascii') as f_obj:
    params = json.load(f_obj)

# СПОСОБЫ ИЗМЕРЕНИЯ EWT

estimators = [
    EWT0(service_ids=params['service_ids'])
]

# КОНФИГУРАЦИЯ ЛОГОВ

logger.remove()
custom_format = (
    "<green>{time:YYYY-MM-DD HH:mm:ss.SSS}</green>\t"
    "<level>{level: <8}</level>\t"
    "<cyan>{name}</cyan>:<cyan>{function}</cyan>:<cyan>{line}</cyan>\t"
    "<level>{message}</level>"
)

# Логи в файл

logger.add('data.csv', level='INFO', format=custom_format)

# Логи в консоль

logger.add(sys.stderr, level='INFO', format=custom_format)
# logger.add(sys.stderr, level='DEBUG', format=custom_format)
# logger.add(sys.stderr, level='TRACE', format=custom_format)

# ЗАПУСК

runner = Runner(
    methods=ConfigurationEEL(),
    general_timer=10,
    services_statuses_recount_timer=5,
    ewt_estimators=[
        EWT0(service_ids=params['service_ids'])
    ],
    logger=logger
)

shared_params = Manager().dict()
shared_params.update({
    key: value for key, value in params.items()})

app = FastAPI()

@app.get('/')
def hello(): return 'hello'

@app.get('/params')
def get_state(): return shared_params

@app.patch('/params')
def set_params(updated_params: CurrentParams):

    d = updated_params.__dict__
    keys = [k for k, v in d.items() if v is not None]
    shared_params.update({key: {sid: value for sid, value in getattr(updated_params, key).items()} for key in keys})

    return shared_params

@app.get("/metrics", response_class=PlainTextResponse)
async def metrics():
    ...

if __name__ == '__main__':

    subprocess = Process(
        target=runner.run,
        args=(shared_params, 0.1, None)) # (shared_params, time_scale, number_of_calls)

    try:
        subprocess.start()
        uvicorn.run(app)
    except KeyboardInterrupt:
        if hasattr(subprocess, 'pid'):
            parent = psutil.Process(subprocess.pid)
            for subchild in parent.children(recursive=True):
                subchild.kill()
        else:
            print(subprocess, 'NO PID')
        subprocess.kill()
        print('Precesses were killed')
        raise
    finally:
        subprocess.join()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 97
#      96 try:
# ---> 97     subprocess.start()
#      98     uvicorn.run(app)
#
# File ~/.pyenv/versions/3.13.9/lib/python3.13/multiprocessing/process.py:121, in BaseProcess.start(self)
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#
# File ~/.pyenv/versions/3.13.9/lib/python3.13/multiprocessing/context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File ~/.pyenv/versions/3.13.9/lib/python3.13/multiprocessing/context.py:289, in SpawnProcess._Popen(process_obj)
#     288 from .popen_spawn_posix import Popen
# --> 289 return Popen(process_obj)
#
# File ~/.pyenv/versions/3.13.9/lib/python3.13/multiprocessing/popen_spawn_posix.py:32, in Popen.__init__(self, process_obj)
#      31 self._fds = []
# ---> 32 super().__init__(process_obj)
#
# File ~/.pyenv/versions/3.13.9/lib/python3.13/multiprocessing/popen_fork.py:20, in Popen.__init__(self, process_obj)
#      19 self.finalizer = None
# ---> 20 self._launch(process_obj)
#
# File ~/.pyenv/versions/3.13.9/lib/python3.13/multiprocessing/popen_spawn_posix.py:47, in Popen._launch(self, process_obj)
#      46     reduction.dump(prep_data, fp)
# ---> 47     reduction.dump(process_obj, fp)
#      48 finally:
#
# File ~/.pyenv/versions/3.13.9/lib/python3.13/multiprocessing/reduction.py:60, in dump(obj, file, protocol)
#      59 '''Replacement for pickle.dump() using ForkingPickler.'''
# ---> 60 ForkingPickler(file, protocol).dump(obj)
#
# TypeError: cannot pickle 'TextIOWrapper' instances
#
# During handling of the above exception, another exception occurred:
#
# AssertionError                            Traceback (most recent call last)
# Cell In[11], line 110
#     108     raise
#     109 finally:
# --> 110     subprocess.join()
#
# File ~/.pyenv/versions/3.13.9/lib/python3.13/multiprocessing/process.py:148, in BaseProcess.join(self, timeout)
#     146 self._check_closed()
#     147 assert self._parent_pid == os.getpid(), 'can only join a child process'
# --> 148 assert self._popen is not None, 'can only join a started process'
#     149 res = self._popen.wait(timeout)
#     150 if res is not None:
#
# AssertionError: can only join a started process
